# %%
import seaborn as sns
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# /Users/shaun/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv("/Users/shaun/Desktop/compiled_df.csv")

# %%
df.head()
# Out:
#   cell_line    transcript_id  transcript_position      start        end  \
# 0      A549  ENST00000547665                  559  760859491  760859690
# 1      A549  ENST00000450744                  889  710329043  710329335
# 2      A549  ENST00000314888                 3452  701519886  701520209
# 3      A549  ENST00000330387                 4761  705936980  705937181
# 4      A549  ENST00000391411                 6156  159215334  159215547
#
#    n_reads  dwelling_t-1     sd_-1     mean_-1  dwelling_t0  ...    knf_CT  \
# 0        2      0.006289  3.765678  110.700000     0.020420  ...  0.000000
# 1        2      0.009228  5.604509  116.700000     0.010925  ...  0.000000
# 2        3      0.004106  5.399771  117.166667     0.004066  ...  0.166667
# 3        2      0.006140  6.374500  103.500000     0.009416  ...  0.000000
# 4        2      0.006267  1.223535   90.300000     0.004827  ...  0.000000
#
#    knf_CG  cksnap_AA  cksnap_AT  cksnap_AC  cksnap_GT  cksnap_GC    js_all  \
# 0     0.0        0.0       0.00       0.75        0.0       0.00  0.666667
# 1     0.0        0.0       0.00       0.25        0.0       0.25  0.666667
# 2     0.0        0.0       0.25       0.25        0.0       0.25  0.511111
# 3     0.0        0.5       0.00       0.25        0.0       0.00  0.666667
# 4     0.0        0.5       0.00       0.00        0.0       0.00  0.583333
#
#        eiip  prediction
# 0  0.122943    0.009351
# 1  0.108829    0.011313
# 2  0.123943    0.287240
# 3  0.128214    0.004840
# 4  0.129286    0.000879
#
# [5 rows x 48 columns]

# %%
df["prediction"].describe()
# Out:
# count    2.664070e+06
# mean     8.162165e-02
# std      1.474657e-01
# min      2.997995e-04
# 25%      7.990206e-03
# 50%      2.361381e-02
# 75%      7.417436e-02
# max      9.574305e-01
# Name: prediction, dtype: float64

# %%
df['label'] = df['prediction'].apply(lambda x: 1 if x > 0.5 else 0)
df
# Out:
#         cell_line    transcript_id  transcript_position       start  \
# 0            A549  ENST00000547665                  559   760859491
# 1            A549  ENST00000450744                  889   710329043
# 2            A549  ENST00000314888                 3452   701519886
# 3            A549  ENST00000330387                 4761   705936980
# 4            A549  ENST00000391411                 6156   159215334
# ...           ...              ...                  ...         ...
# 2664065     HepG2  ENST00000595661                  535   676623619
# 2664066     HepG2  ENST00000509967                 4822  2066753654
# 2664067     HepG2  ENST00000569636                  640   882255390
# 2664068     HepG2  ENST00000571589                 5826   660453008
# 2664069     HepG2  ENST00000392108                 3600  1309463977
#
#                 end  n_reads  dwelling_t-1     sd_-1     mean_-1  dwelling_t0  \
# 0         760859690        2      0.006289  3.765678  110.700000     0.020420
# 1         710329335        2      0.009228  5.604509  116.700000     0.010925
# 2         701520209        3      0.004106  5.399771  117.166667     0.004066
# 3         705937181        2      0.006140  6.374500  103.500000     0.009416
# 4         159215547        2      0.006267  1.223535   90.300000     0.004827
# ...             ...      ...           ...       ...         ...          ...
# 2664065   676624056        4      0.008062  2.623278  120.900000     0.010874
# 2664066  2066753772        1      0.003980  4.037000  129.500000     0.011961
# 2664067   882255543        1      0.004980  2.636000  117.700000     0.003233
# 2664068   660453211        2      0.002990  3.336000  117.500000     0.005761
# 2664069  1309464136        1      0.005993  6.455472  115.000000     0.009132
#
#          ...  knf_CG  cksnap_AA  cksnap_AT  cksnap_AC  cksnap_GT  cksnap_GC  \
# 0        ...     0.0       0.00       0.00       0.75       0.00       0.00
# 1        ...     0.0       0.00       0.00       0.25       0.00       0.25
# 2        ...     0.0       0.00       0.25       0.25       0.00       0.25
# 3        ...     0.0       0.50       0.00       0.25       0.00       0.00
# 4        ...     0.0       0.50       0.00       0.00       0.00       0.00
# ...      ...     ...        ...        ...        ...        ...        ...
# 2664065  ...     0.0       0.00       0.25       0.00       0.25       0.25
# 2664066  ...     0.0       0.00       0.25       0.25       0.25       0.00
# 2664067  ...     0.0       0.00       0.00       0.25       0.00       0.50
# 2664068  ...     0.0       0.50       0.00       0.25       0.00       0.00
# 2664069  ...     0.0       0.25       0.00       0.25       0.00       0.25
#
#            js_all      eiip  prediction  label
# 0        0.666667  0.122943    0.009351      0
# 1        0.666667  0.108829    0.011313      0
# 2        0.511111  0.123943    0.287240      0
# 3        0.666667  0.128214    0.004840      0
# 4        0.583333  0.129286    0.000879      0
# ...           ...       ...         ...    ...
# 2664065  0.511111  0.117386    0.031007      0
# 2664066  0.511111  0.123871    0.001654      0
# 2664067  0.583333  0.117529    0.303932      0
# 2664068  0.600000  0.120657    0.252910      0
# 2664069  0.511111  0.122871    0.020533      0
#
# [2664070 rows x 49 columns]

# %%
df.columns
# Out:
# Index(['cell_line', 'transcript_id', 'transcript_position', 'start', 'end',
#        'n_reads', 'dwelling_t-1', 'sd_-1', 'mean_-1', 'dwelling_t0', 'sd_0',
#        'mean_0', 'dwelling_t1', 'sd_1', 'mean_1', 'nucleo_-3_A', 'nucleo_-3_G',
#        'nucleo_-3_T', 'nucleo_-2_A', 'nucleo_-2_G', 'nucleo_-1_G',
#        'nucleo_2_C', 'nucleo_2_T', 'nucleo_2_A', 'nucleo_3_A', 'nucleo_3_G',
#        'nucleo_3_T', 'nucleo_3_C', 'pwm_score', 'knf_AA', 'knf_AG', 'knf_AT',
#        'knf_AC', 'knf_GG', 'knf_TT', 'knf_TA', 'knf_TG', 'knf_CA', 'knf_CT',
#        'knf_CG', 'cksnap_AA', 'cksnap_AT', 'cksnap_AC', 'cksnap_GT',
#        'cksnap_GC', 'js_all', 'eiip', 'prediction', 'label'],
#       dtype='object')

# %%
df[(df["cell_line"] == "HepG2") & (df["label"] == 0)]
# Out:
#         cell_line    transcript_id  transcript_position       start  \
# 2034915     HepG2  ENST00000459772                 2363   859811170
# 2034916     HepG2  ENST00000607537                  213  2065241005
# 2034917     HepG2  ENST00000377767                 7016   485121636
# 2034918     HepG2  ENST00000377807                 1102  2668690980
# 2034919     HepG2  ENST00000313234                 1328  1649077190
# ...           ...              ...                  ...         ...
# 2664065     HepG2  ENST00000595661                  535   676623619
# 2664066     HepG2  ENST00000509967                 4822  2066753654
# 2664067     HepG2  ENST00000569636                  640   882255390
# 2664068     HepG2  ENST00000571589                 5826   660453008
# 2664069     HepG2  ENST00000392108                 3600  1309463977
#
#                 end  n_reads  dwelling_t-1     sd_-1  mean_-1  dwelling_t0  \
# 2034915   859811297        1      0.003980  5.859000   100.30     0.004980
# 2034916  2065241133        1      0.002990  2.247000   125.90     0.005640
# 2034917   485121852        2      0.012230  4.917660   129.85     0.017430
# 2034918  2668691134        1      0.013937  7.574398   116.80     0.007908
# 2034919  1649077431        2      0.005157  2.532559   106.65     0.003266
# ...             ...      ...           ...       ...      ...          ...
# 2664065   676624056        4      0.008062  2.623278   120.90     0.010874
# 2664066  2066753772        1      0.003980  4.037000   129.50     0.011961
# 2664067   882255543        1      0.004980  2.636000   117.70     0.003233
# 2664068   660453211        2      0.002990  3.336000   117.50     0.005761
# 2664069  1309464136        1      0.005993  6.455472   115.00     0.009132
#
#          ...    knf_CG  cksnap_AA  cksnap_AT  cksnap_AC  cksnap_GT  cksnap_GC  \
# 2034915  ...  0.000000       0.25       0.00       0.25       0.00       0.00
# 2034916  ...  0.000000       0.00       0.25       0.25       0.00       0.25
# 2034917  ...  0.000000       0.25       0.25       0.00       0.00       0.25
# 2034918  ...  0.000000       0.25       0.00       0.25       0.00       0.25
# 2034919  ...  0.166667       0.25       0.00       0.50       0.00       0.00
# ...      ...       ...        ...        ...        ...        ...        ...
# 2664065  ...  0.000000       0.00       0.25       0.00       0.25       0.25
# 2664066  ...  0.000000       0.00       0.25       0.25       0.25       0.00
# 2664067  ...  0.000000       0.00       0.00       0.25       0.00       0.50
# 2664068  ...  0.000000       0.50       0.00       0.25       0.00       0.00
# 2664069  ...  0.000000       0.25       0.00       0.25       0.00       0.25
#
#            js_all      eiip  prediction  label
# 2034915  0.550000  0.114171    0.042796      0
# 2034916  0.583333  0.116386    0.008323      0
# 2034917  0.511111  0.115243    0.051255      0
# 2034918  0.583333  0.115314    0.321187      0
# 2034919  0.638889  0.121800    0.007682      0
# ...           ...       ...         ...    ...
# 2664065  0.511111  0.117386    0.031007      0
# 2664066  0.511111  0.123871    0.001654      0
# 2664067  0.583333  0.117529    0.303932      0
# 2664068  0.600000  0.120657    0.252910      0
# 2664069  0.511111  0.122871    0.020533      0
#
# [601580 rows x 49 columns]

# %%
sns.histplot(x = df['cell_line'], hue=df['label'], multiple="dodge", 
                  stat = 'density', shrink = 0.8, common_norm=False)
# Out:
# <Axes: xlabel='cell_line', ylabel='Density'>

# %%
for column in ['nucleo_-3_A', 'nucleo_-3_G',
       'nucleo_-3_T', 'nucleo_-2_A', 'nucleo_-2_G', 'nucleo_-1_G',
       'nucleo_2_C', 'nucleo_2_T', 'nucleo_2_A', 'nucleo_3_A', 'nucleo_3_G',
       'nucleo_3_T', 'nucleo_3_C']:
    sns.countplot(data=df, x=column, hue='label', stat="probability")
    plt.show()
